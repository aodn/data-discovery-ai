# %% [markdown]
# # AI/ML tasks Demo
# ## Demonstrated AI/ML Tasks
# - Data delivery mode classification (ML)
# - Description reformating (AI)
# - Link grouping (AI)
# ### Data Delivery Mode Classification
# - Background: [AODN Portal](https://portal.edge.aodn.org.au/)
# - Example: [IMOS - OceanCurrent - Gridded sea level anomaly - Near real time](https://portal.edge.aodn.org.au/details?uuid=0c9eb39c-9cbe-4c6a-8a10-5867087e703a&tab=summary) and [IMOS - ANFOG - Delayed Mode QA/QC Best Practice Manual](https://portal.edge.aodn.org.au/details?uuid=b82ec5c4-3b6a-4a39-a4e7-f1adba2d5372&tab=summary)
# - Exception: No exilipt "Real-Time" or "Delayed" in the title. It can be sometimes wrong if we use decision-making rules. E.g.
# > "The other data is delivered in real-time, but this one is delivered in delayed mode instead."
#
# [IMOS SOOP-XBT Upper Ocean Thermal Data collected on the line IX21 (Cape of Good Hope - Mauritius)](https://portal.edge.aodn.org.au/details?uuid=0443254b-fd39-468f-923f-1469f8caa9aa)
#
# **Demo Request** on /datadeliverymode

# %%
{
    "selected_model": "development",
    "title": "a test dataset",
    "abstract": "The other data is delivered in real-time, but this one is delivered in delayed mode instead.",
    "lineage": ""
}

# %% [markdown]
# ### Description Formatting
# - Background: long paragraphs hard to read. e.g.[Sensors on Tropical Research Vessels: Enhanced Measurements from Ships of Opportunity (SOOP)](https://portal.edge.aodn.org.au/details?uuid=8af21108-c535-43bf-8dab-c1f45a26088c)
#
# **Demo Request** on /descriptionformatter

# %%
{
    "selected_model": "openai",
    "title": "Sensors on Tropical Research Vessels: Enhanced Measurements from Ships of Opportunity (SOOP)",
    "abstract": "The research vessels (RV Cape Ferguson and RV Solander) of the Australian Institute of Marine Science (AIMS) routinely record along-track (underway) measurements of near-surface water temperature, salinity, chlorophyll (fluorescence) and turbidity (NTU) during scientific operations in the tropical waters of northern Australia, particularly the Great Barrier Reef (GBR). All data records include sampling time (UTC), position (Latitude, Longitude) and water depth (under keel). \n\nData are recorded at 10 second intervals. Data are measured with a Seabird SBE38 thermometer, Seabird SBE21 thermosalinograph and Wetlabs ECO-FLNTU-RT (optical sensor for chlorophyll fluorescence and turbidity). The turbidity data (NTU) are currently regarded as provisional in the absence of local validation due to intermittent bubble contamination. The sampling intakes are located at depths of 1.9m (RV Cape Ferguson) and 2.5m (RV Solander).\n\nThe data is used to inform spatial patchiness of these variables and for ongoing validation of satellite ocean temperature and ocean colour products.\n\nThe IMOS Ships of Opportunity, Sensors on Tropical Research Vessels sub-Facility was discontinued in June 2022. Sea surface temperature data collected by Australian Institute of Marine Science research vessels continues to be provided via the IMOS Ships of Opportunity, Sea Surface Temperature Sensors for Australian Vessels sub-Facility records on the AODN Portal. The near real time sea surface temperature data are quality controlled by the Australian Bureau of Meteorology and uploaded onto the Global Telecommunication System (GTS) for global dissemination to be used in real time sea surface temperature analyses and climate data records. Access to the additional data collected by the AIMS research vessels, is provided on the AIMS data repository here: https://apps.aims.gov.au/metadata/view/8af21108-c535-43bf-8dab-c1f45a26088c."
}

# %%
input = """DESCRIPTION WITH MULTIPLE LINES"""

# %%
input = input.replace('"', "'").replace('\n', '\\n')
input

# %%
output = """# Sensors on Tropical Research Vessels: Enhanced Measurements from Ships of Opportunity (SOOP)\n\nThe research vessels (RV Cape Ferguson and RV Solander) of the Australian Institute of Marine Science (AIMS) routinely record along-track (underway) measurements of near-surface water temperature, salinity, chlorophyll (fluorescence) and turbidity (NTU) during scientific operations in the tropical waters of northern Australia, particularly the Great Barrier Reef (GBR). All data records include sampling time (UTC), position (Latitude, Longitude) and water depth (under keel).\n\nData are recorded at 10 second intervals. Data are measured with:\n- a Seabird SBE38 thermometer\n- Seabird SBE21 thermosalinograph\n- Wetlabs ECO-FLNTU-RT (optical sensor for chlorophyll fluorescence and turbidity)\n\nThe turbidity data (NTU) are currently regarded as provisional in the absence of local validation due to intermittent bubble contamination. The sampling intakes are located at depths of 1.9m (RV Cape Ferguson) and 2.5m (RV Solander).\n\nThe data is used to inform spatial patchiness of these variables and for ongoing validation of satellite ocean temperature and ocean colour products.\n\nThe IMOS Ships of Opportunity, Sensors on Tropical Research Vessels sub-Facility was discontinued in June 2022. Sea surface temperature data collected by Australian Institute of Marine Science research vessels continues to be provided via the IMOS Ships of Opportunity, Sea Surface Temperature Sensors for Australian Vessels sub-Facility records on the AODN Portal. The near real time sea surface temperature data are quality controlled by the Australian Bureau of Meteorology and uploaded onto the Global Telecommunication System (GTS) for global dissemination to be used in real time sea surface temperature analyses and climate data records. Access to the additional data collected by the AIMS research vessels, is provided on the AIMS data repository here: [AIMS Data Repository](https://apps.aims.gov.au/metadata/view/8af21108-c535-43bf-8dab-c1f45a26088c)."""

# %%
output = output.replace("\n", "  \n")
output = output.replace("\*", "*")
print(output)
# Out:
# # Sensors on Tropical Research Vessels: Enhanced Measurements from Ships of Opportunity (SOOP)
#
# The research vessels (RV Cape Ferguson and RV Solander) of the Australian Institute of Marine Science (AIMS) routinely record along-track (underway) measurements of near-surface water temperature, salinity, chlorophyll (fluorescence) and turbidity (NTU) during scientific operations in the tropical waters of northern Australia, particularly the Great Barrier Reef (GBR). All data records include sampling time (UTC), position (Latitude, Longitude) and water depth (under keel).
#
# Data are recorded at 10 second intervals. Data are measured with:
# - a Seabird SBE38 thermometer
# - Seabird SBE21 thermosalinograph
# - Wetlabs ECO-FLNTU-RT (optical sensor for chlorophyll fluorescence and turbidity)
#
# The turbidity data (NTU) are currently regarded as provisional in the absence of local validation due to intermittent bubble contamination. The sampling intakes are located at depths of 1.9m (RV Cape Ferguson) and 2.5m (RV Solander).
#
# The data is used to inform spatial patchiness of these variables and for ongoing validation of satellite ocean temperature and ocean colour products.
#
# The IMOS Ships of Opportunity, Sensors on Tropical Research Vessels sub-Facility was discontinued in June 2022. Sea surface temperature data collected by Australian Institute of Marine Science research vessels continues to be provided via the IMOS Ships of Opportunity, Sea Surface Temperature Sensors for Australian Vessels sub-Facility records on the AODN Portal. The near real time sea surface temperature data are quality controlled by the Australian Bureau of Meteorology and uploaded onto the Global Telecommunication System (GTS) for global dissemination to be used in real time sea surface temperature analyses and climate data records. Access to the additional data collected by the AIMS research vessels, is provided on the AIMS data repository here: [AIMS Data Repository](https://apps.aims.gov.au/metadata/view/8af21108-c535-43bf-8dab-c1f45a26088c).

# %% [markdown]
# # Sensors on Tropical Research Vessels: Enhanced Measurements from Ships of Opportunity (SOOP)
#
# The research vessels (RV Cape Ferguson and RV Solander) of the Australian Institute of Marine Science (AIMS) routinely record along-track (underway) measurements of near-surface water temperature, salinity, chlorophyll (fluorescence) and turbidity (NTU) during scientific operations in the tropical waters of northern Australia, particularly the Great Barrier Reef (GBR). All data records include sampling time (UTC), position (Latitude, Longitude) and water depth (under keel).
#
# Data are recorded at 10 second intervals. Data are measured with:
# - a Seabird SBE38 thermometer
# - Seabird SBE21 thermosalinograph
# - Wetlabs ECO-FLNTU-RT (optical sensor for chlorophyll fluorescence and turbidity)
#
# The turbidity data (NTU) are currently regarded as provisional in the absence of local validation due to intermittent bubble contamination. The sampling intakes are located at depths of 1.9m (RV Cape Ferguson) and 2.5m (RV Solander).
#
# The data is used to inform spatial patchiness of these variables and for ongoing validation of satellite ocean temperature and ocean colour products.
#
# The IMOS Ships of Opportunity, Sensors on Tropical Research Vessels sub-Facility was discontinued in June 2022. Sea surface temperature data collected by Australian Institute of Marine Science research vessels continues to be provided via the IMOS Ships of Opportunity, Sea Surface Temperature Sensors for Australian Vessels sub-Facility records on the AODN Portal. The near real time sea surface temperature data are quality controlled by the Australian Bureau of Meteorology and uploaded onto the Global Telecommunication System (GTS) for global dissemination to be used in real time sea surface temperature analyses and climate data records. Access to the additional data collected by the AIMS research vessels, is provided on the AIMS data repository here: [AIMS Data Repository](https://apps.aims.gov.au/metadata/view/8af21108-c535-43bf-8dab-c1f45a26088c).

# %% [markdown]
# ### Link grouping
# - Background: grouping links by their usage:
# 1. Data Access
# 2. Documentation
# 3. Python Notebook
# 4. Others
#
# - Example: [Sensors on Tropical Research Vessels: Enhanced Measurements from Ships of Opportunity (SOOP)](https://portal.edge.aodn.org.au/details?uuid=8af21108-c535-43bf-8dab-c1f45a26088c&tab=data-access)
#
# **Demo Request** on /grouplinks

# %%
{
    "links": [
            {
              "href": "http://data.aims.gov.au/extpubs/do/viewPub.do?articleId=8541",
              "rel": "related",
              "type": "",
              "title": "Enhancing ship of opportunity sea surface temperature observations in the Australian region"
            },
            {
              "href": "http://imos.org.au/tropicalresearchvessels.html",
              "rel": "related",
              "type": "text/html",
              "title": "IMOS: Sensors on Tropical Research Vessels"
            },
            {
              "href": "http://thredds.aodn.org.au/thredds/catalog/IMOS/SOOP/SOOP-TRV/catalog.html",
              "rel": "related",
              "type": "text/html",
              "title": "NetCDF files via THREDDS catalog"
            },
            {
              "href": "https://portal.aodn.org.au/search?uuid=8af21108-c535-43bf-8dab-c1f45a26088c",
              "rel": "related",
              "type": "text/html",
              "title": "View and download data though the AODN Portal"
            },
            {
              "href": "http://geoserver-123.aodn.org.au/geoserver/wms",
              "rel": "wms",
              "type": "",
              "title": "imos:soop_trv_trajectory_map"
            },
            {
              "href": "http://geoserver-123.aodn.org.au/geoserver/ows",
              "rel": "wfs",
              "type": "",
              "title": "soop_trv_trajectory_data"
            },
            {
              "href": "https://help.aodn.org.au/web-services/ogc-wfs/",
              "rel": "related",
              "type": "text/html",
              "title": "OGC WFS help documentation"
            },
            {
              "href": "https://registry.opendata.aws/aodn_vessel_trv_realtime_qc/",
              "rel": "related",
              "type": "text/html",
              "title": "Access To AWS Open Data Program registry for the Cloud Optimised version of this dataset"
            },
            {
              "href": "https://nbviewer.org/github/aodn/aodn_cloud_optimised/blob/main/notebooks/vessel_trv_realtime_qc.ipynb",
              "rel": "related",
              "type": "text/html",
              "title": "Access to Jupyter notebook to query Cloud Optimised converted dataset"
            },
            {
              "href": "https://geonetwork-edge.edge.aodn.org.au:443/geonetwork/images/harvesting/IMOS_colour_logo.png",
              "rel": "icon",
              "type": "image/png",
              "title": "Suggest icon for dataset"
            },
            {
              "href": "https://catalogue-imos.aodn.org.au:443/geonetwork/srv/api/records/8af21108-c535-43bf-8dab-c1f45a26088c",
              "rel": "describedby",
              "type": "text/html",
              "title": "Full metadata link"
            },
            {
              "href": "https://licensebuttons.net/l/by/4.0/88x31.png",
              "rel": "license",
              "type": "image/png"
            },
            {
              "href": "http://creativecommons.org/licenses/by/4.0/",
              "rel": "license",
              "type": "text/html"
            },
            {
              "href": "https://nbviewer.org/github/aodn/aodn_cloud_optimised/blob/main/notebooks/vessel_trv_realtime_qc.ipynb",
              "rel": "related",
              "type": "application/json",
              "title": "Python notebook example"
            }
          ]
}

# %% [markdown]
# **Demo request** on /processrecord

# %%
{
    "selected_model": "development",
    "document_id": "8e00907f-716d-4080-b212-534fcd78a602"
}
